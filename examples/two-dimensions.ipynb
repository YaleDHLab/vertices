# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

import sys
[sys.path.append(i) for i in ['..']]

from vertices import ImgParser

# parse an object file
img = ImgParser('dylan.jpg')

# %%
# check the number of vertices identified in the raw input image
verts = img.vertices
verts.shape
# Out:
# (117762, 2)

# %%
# plot the vertices in the raw input image
img.plot(verts, figscale=0.015)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# resize the input image so it has n vertices
n = 1000000
verts = img.get_n_vertices(n)

# %%
img.plot(verts, figscale=0.01, s=0.0001) # million vertex bash
# Out:
# <img src="data:image/png;base64,..." width="400">
