# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

import sys
[sys.path.append(i) for i in ['..']]

from vertices import ObjParser

# parse an object file
obj = ObjParser('bunny.obj')

# %%
# extract the initial vertex set on the bunny.obj file
verts = obj.vertices

# %%
# check the shape of the vertices
verts.shape
# Out:
# (2503, 3)

# %%
# plot the initial vertex set
obj.plot(verts)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# expand the bunny geometry to 50,000 vertices and plot the result
verts = obj.get_n_vertices(50000)
# Out:
#  * adding vertices

# %%
# check the new vertex shape
verts.shape
# Out:
# (50000, 3)

# %%
obj.plot(verts)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# reduce the number of vertices in the geometry
verts = obj.get_n_vertices(1000)
# Out:
#  * removing vertices

# %%
# check the new vertex shape
verts.shape
# Out:
# (1000, 3)

# %%
obj.plot(verts)
# Out:
# <img src="data:image/png;base64,..." width="640">
